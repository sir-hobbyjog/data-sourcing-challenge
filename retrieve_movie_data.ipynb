# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
# filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = f"{url}api-key={nyt_api_key}&sort={sort}&begin_date={begin_date}&end_date={end_date}&fl={field_list}&q={filter_query}"
print(query_url)
# Out:
# https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=hr9nxEfJkqWtaRrpGQuwWutYTIOsb0Xi&sort=newest&begin_date=20130101&end_date=20230531&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count&q=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page in range(0, 19):
    

    # create query with a page number
    query_url = url + f"api-key={nyt_api_key}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}&page={page}"

    # API results show 10 articles at a time

    # Make a "GET" request and retrieve the JSON
    response = requests.get(query_url)
    reviews = response.json()

    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            reviews_list.append(review)

        # Print the page that was just retrieved
        print(f"Retrieved page {page} of reviews")

        # Print the page number that had no results then break from the loop
    except IndexError or KeyError:
        print(f"Page {page} has no results")
        break
# Out:
# Retrieved page 0 of reviews
# Retrieved page 1 of reviews
# Retrieved page 2 of reviews
# Retrieved page 3 of reviews
# Retrieved page 4 of reviews
# Retrieved page 5 of reviews
# Retrieved page 6 of reviews
# Retrieved page 7 of reviews
# Retrieved page 8 of reviews
# Retrieved page 9 of reviews
# Retrieved page 10 of reviews
# Retrieved page 11 of reviews
# Retrieved page 12 of reviews
# Retrieved page 13 of reviews
# Retrieved page 14 of reviews
# Retrieved page 15 of reviews
# Retrieved page 16 of reviews
# Retrieved page 17 of reviews
# Retrieved page 18 of reviews

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list[:5], indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Diment, Valentin Javier",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-25T11:00:03+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 295
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html",
#         "snippet": "Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "Review: \u2018What\u2019s Love Got to Do With It?\u2019 Probably a Lot",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "What\u2019s Love Got to Do With It?",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Kapur, Shekhar",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "James, Lily",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Azmi, Shabana",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Thompson, Emma",
#                 "rank": 5,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T17:16:45+0000",
#         "byline": {
#             "original": "By Jeannette Catsoulis",
#             "person": [
#                 {
#                     "firstname": "Jeannette",
#                     "middlename": null,
#                     "lastname": "Catsoulis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 287
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html",
#         "snippet": "Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018You Can Live Forever\u2019 Review: Do You Love Me Now?",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "You Can Live Forever",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "You Can Live Forever (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Slutsky, Mark",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Watts, Sarah (Film Director)",
#                 "rank": 4,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "O'Driscoll, Anwen",
#                 "rank": 5,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Laporte, June (Actor)",
#                 "rank": 6,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-05-04T11:00:08+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 294
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html",
#         "snippet": "Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018A Tourist\u2019s Guide to Love\u2019 Review: A Wearyingly Familiar Trip",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "A Tourist\u2019s  Guide to Love",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "A Tourist's Guide to Love (Movie)",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Tsuchida, Steven",
#                 "rank": 3,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Cook, Rachael Leigh",
#                 "rank": 4,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-21T07:03:25+0000",
#         "byline": {
#             "original": "By Elisabeth Vincentelli",
#             "person": [
#                 {
#                     "firstname": "Elisabeth",
#                     "middlename": null,
#                     "lastname": "Vincentelli",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 276
#     },
#     {
#         "web_url": "https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html",
#         "snippet": "A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone\u2019s lives.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018Other People\u2019s Children\u2019 Review: True Romance",
#             "kicker": "Critic\u2019s pick",
#             "content_kicker": null,
#             "print_headline": "Intoxicating Love With a Sobering Turn",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "persons",
#                 "value": "Zlotowski, Rebecca",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "Other People's Children (Movie)",
#                 "rank": 3,
#                 "major": "N"
#             }
#         ],
#         "pub_date": "2023-04-20T15:35:13+0000",
#         "byline": {
#             "original": "By Manohla Dargis",
#             "person": [
#                 {
#                     "firstname": "Manohla",
#                     "middlename": null,
#                     "lastname": "Dargis",
#                     "qualifier": null,
#                     "title": null,
#                     "role": "reported",
#                     "organization": "",
#                     "rank": 1
#                 }
#             ],
#             "organization": null
#         },
#         "word_count": 801
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 1  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 2  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 3  [{'name': 'subject', 'value': 'Movies', 'rank'...
# 4  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
reviews_df["title"] = reviews_df["headline.main"]
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"] = reviews_df["title"].apply(lambda text: text[text.find('\u2018')+1 : text.rfind('\u2019')] if '\u2018' in text and '\u2019' in text else text)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                             title
# 0          The Attachment Diaries
# 1  What’s Love Got to Do With It?
# 2            You Can Live Forever
# 3       A Tourist’s Guide to Love
# 4         Other People’s Children

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df["keywords"] = reviews_df["keywords"].apply(extract_keywords)
reviews_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/what...
# 2  https://www.nytimes.com/2023/05/04/movies/you-...
# 3  https://www.nytimes.com/2023/04/21/movies/a-to...
# 4  https://www.nytimes.com/2023/04/20/movies/othe...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Two childhood friends navigate cultural differ...  The New York Times
# 2  Religion comes between two girls falling in lo...  The New York Times
# 3  Rachael Leigh Cook stars in this bland rom-com...  The New York Times
# 4  A radiant Virginie Efira stars as a Parisian t...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;persons: Kapur, Shekhar;person...
# 2  subject: Movies;creative_works: You Can Live F...
# 3  subject: Movies;creative_works: A Tourist's Gu...
# 4  subject: Movies;persons: Zlotowski, Rebecca;cr...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T17:16:45+0000         287
# 2  2023-05-04T11:00:08+0000         294
# 3  2023-04-21T07:03:25+0000         276
# 4  2023-04-20T15:35:13+0000         801
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  Review: ‘What’s Love Got to Do With It?’ Proba...            None
# 2  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 3  ‘A Tourist’s Guide to Love’ Review: A Wearying...            None
# 4     ‘Other People’s Children’ Review: True Romance   Critic’s pick
#
#   headline.content_kicker                 headline.print_headline  \
# 0                    None                  The Attachment Diaries
# 1                    None          What’s Love Got to Do With It?
# 2                    None                    You Can Live Forever
# 3                    None              A Tourist’s  Guide to Love
# 4                    None  Intoxicating Love With a Sobering Turn
#
#   headline.name headline.seo headline.sub           byline.original  \
# 0          None         None         None    By Jeannette Catsoulis
# 1          None         None         None    By Jeannette Catsoulis
# 2          None         None         None  By Elisabeth Vincentelli
# 3          None         None         None  By Elisabeth Vincentelli
# 4          None         None         None         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Jeannette', 'middlename': None...                None
# 2  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 3  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                                    title
# 0          The Attachment Diaries Review
# 1  What’s Love Got to Do With It? Review
# 2            You Can Live Forever Review
# 3       A Tourist’s Guide to Love Review
# 4         Other People’s Children Review

# %%
# Create a list from the "title" column using to_list() and remove " Review" from each title
titles = reviews_df["title"].str.replace(" Review", "").to_list()
# These titles will be used in the query for The Movie Database
print(titles)
# Out:
# ['The Attachment Diaries', 'What’s Love Got to Do With It?', 'You Can Live Forever', 'A Tourist’s Guide to Love', 'Other People’s Children', 'One True Loves', 'The Lost Weekend: A Love Story', 'A Thousand and One', 'Your Place or Mine', 'Love in the Time of Fentanyl', 'Pamela, a Love Story', 'In From the Side', 'After Love', 'Alcarràs', 'Nelly & Nadine', 'Lady Chatterley’s Lover', 'The Sound of Christmas', 'The Inspection', 'Bones and All', 'My Policeman', 'About Fate’: Love the One You', 'Waiting for Bojangles', 'I Love My Dad', 'A Love Song', 'Alone Together', 'Art of Love', 'The Wheel', 'Thor: Love and Thunder’: A God', 'Both Sides of the Blade', 'Fire of Love', 'Love & Gelato', 'Stay Prayed Up', 'Benediction’: A Poet', 'Dinner in America', 'In a New York Minute', 'Anaïs in Love', 'I Love America', 'See You Then', 'La Mami', 'Love After Love', 'Deep Water', 'Lucy and Desi', 'Cyrano', 'The In Between', 'Book of Love', 'Lingui, the Sacred Bonds', 'The Pink Cloud', 'A Journal for Jordan', 'West Side Story', 'Aulcie', 'Love Is Love Is Love', 'Love Hard', 'Bergman Island', 'Hard Luck Love Song', 'South of Heaven', 'Wife of a Spy', 'Happier Than Ever', 'Together', 'Annette', 'Resort to Love', 'Woodstock 99: Peace, Love and Rage', 'Casanova, Last Love', 'Running Against the Wind', 'Asia', 'Undine', 'This Town', 'Tu Me Manques', 'Monday', 'Ride or Die', 'Future People', 'Luz', 'Happily', 'This Is the Life', 'To All the Boys: Always and Forever', 'Young Hearts', 'Little Fish', 'Two of Us', 'Atlantis', 'Preparations to Be Together', 'Your Name Engraved Herein', 'Sylvie’s Love', 'Ariana Grande: Excuse Me, I Love You’: It', 'Museum Town', 'Wild Mountain Thyme', 'My Psychedelic Love Story', '69: The Saga of Danny Hernandez', 'Ammonite', 'Love and Monsters', 'Dick Johnson Is Dead’: A Father', 'Love, Guaranteed', 'Feel the Beat', 'Babyteeth', 'Spelling the Dream', 'A Secret Love’: A Lesbian Couple', 'Love Wedding Repeat', 'Almost Love', 'Hope Gap', 'All the Bright Places', 'The Photograph', 'You Go to My Head', 'Ordinary Love', 'To All the Boys: P.S. I Still Love You', 'The Woman Who Loves Giraffes', 'Queen & Slim', 'Marriage Story', 'Cyrano, My Love', 'Pretenders', 'First Love', 'Loro', 'Falling Inn Love', 'Hot Air', 'Love, Antosha’: A Heartbreaking Look at an Actor', 'Leto', 'The Tomorrow Man', 'Asako I & II', 'The Sun Is Also a Star', 'Shéhérazade', 'Long Shot', 'Clara’: Love Means Never Having to Say You', 'Kalank', 'Rafiki', 'Diane', 'Five Feet Apart', 'Ash Is Purest White', 'Gloria Bell', 'Black Mother', 'The Hole in the Ground’: A Horror Film Is Suffocated by a Mother', 'How to Train Your Dragon: The Hidden World', 'A Tuba to Cuba', 'Fighting With My Family', 'Sorry Angel', 'Berlin, I Love You', 'Untogether', 'Cold War', 'If Beale Street Could Talk', 'Asher', 'The Party’s Just Beginning', 'The Great Pretender', 'Sicilian Ghost Story', 'The New Romantic', 'Pimp', 'In a Relationship', 'They’ll Love Me When I’m Dead’ Documents Orson Welles', 'Burning,', 'After Everything,', 'Quincy', 'Love, Gilda,', 'Tea With the Dames,', 'Bel Canto,', 'The Citizen,', 'Love, Cecil,', 'How to Talk to Girls at Parties', 'Rogers Park,', 'Love & Bananas,', 'Godard Mon Amour', 'Submergence,', 'Love After Love,', 'Outside In', 'Love, Simon,', 'Keep the Change,', 'The Party', 'The Housemaid,', 'Forever My Girl,', 'Kangaroo: A Love-Hate Story', 'Lover for a Day', 'Youth,’ the People', 'Killing for Love', 'The Shape of Water', 'Love Beats Rhymes,', 'Cuba and the Cameraman', 'On the Beach at Night Alone', 'Thelma,', 'Hello Again,', 'It Happened in L.A.,', 'God’s Own Country', 'The Mountain Between Us', 'Dina,', 'In Search of Fellini', 'Woodpeckers,', 'I Do ... Until I Don’t,', 'Tales of an Immoral Couple', 'After Love', 'The Last Face', 'Women Who Kill,', 'False Confessions,’ the Play', 'Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinema', 'The Big Sick,', 'Lost in Paris', 'Vincent N Roxxy,', 'Everything, Everything']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 1


# Loop through the titles
for title in titles:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0:
        time.sleep(12)

    # Add 1 to the request counter
    request_counter += 1
    
    # Perform a "GET" request for The Movie Database
    response = requests.get(url + str(title) + tmdb_key_string)

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_id = response.json()["results"][0]["id"]

        # Make a request for a the full movie details
        # Execute "GET" request with url
        movie_response = requests.get(f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}")
        movie_details = movie_response.json()
        
        # Extract the genre names into a list
        genres = []
        for genre in movie_details["genres"]:
            genres.append(genre["name"])


        # Extract the spoken_languages' English name into a list
        spoken_languages = []
        for language in movie_details["spoken_languages"]:
            spoken_languages.append(language["english_name"])

        # Extract the production_countries' name into a list
        production_countries = []
        for country in movie_details["production_countries"]:
            production_countries.append(country["name"])

        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
        tmdb_movies_list.append({
            "title": movie_details["title"],
            "release_date": movie_details["release_date"],
            "budget": movie_details["budget"],
            "revenue": movie_details["revenue"],
            "genres": genres,
            "spoken_languages": spoken_languages,
            "production_countries": production_countries
        })
        
        # Print out the title that was found
        print(f"Found {title}")
    
    except IndexError or KeyError:
        print(f"{title} not found")
# Out:
# Found The Attachment Diaries
# Found What’s Love Got to Do With It?
# Found You Can Live Forever
# Found A Tourist’s Guide to Love
# Found Other People’s Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, a Love Story
# Found In From the Side
# Found After Love
# Found Alcarràs
# Found Nelly & Nadine
# Found Lady Chatterley’s Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# About Fate’: Love the One You not found
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Art of Love
# Found The Wheel
# Thor: Love and Thunder’: A God not found
# Found Both Sides of the Blade
# Found Fire of Love
# Found Love & Gelato
# Found Stay Prayed Up
# Benediction’: A Poet not found
# Found Dinner in America
# Found In a New York Minute
# Found Anaïs in Love
# Found I Love America
# Found See You Then
# Found La Mami
# Found Love After Love
# Found Deep Water
# Found Lucy and Desi
# Found Cyrano
# Found The In Between
# Found Book of Love
# Found Lingui, the Sacred Bonds
# Found The Pink Cloud
# Found A Journal for Jordan
# Found West Side Story
# Aulcie not found
# Found Love Is Love Is Love
# Found Love Hard
# Found Bergman Island
# Found Hard Luck Love Song
# Found South of Heaven
# Found Wife of a Spy
# Found Happier Than Ever
# Found Together
# Found Annette
# Found Resort to Love
# Found Woodstock 99: Peace, Love and Rage
# Found Casanova, Last Love
# Found Running Against the Wind
# Found Asia
# Found Undine
# Found This Town
# Found Tu Me Manques
# Found Monday
# Found Ride or Die
# Found Future People
# Found Luz
# Found Happily
# Found This Is the Life
# Found To All the Boys: Always and Forever
# Found Young Hearts
# Found Little Fish
# Found Two of Us
# Found Atlantis
# Found Preparations to Be Together
# Found Your Name Engraved Herein
# Found Sylvie’s Love
# Ariana Grande: Excuse Me, I Love You’: It not found
# Found Museum Town
# Found Wild Mountain Thyme
# Found My Psychedelic Love Story
# Found 69: The Saga of Danny Hernandez
# Found Ammonite
# Found Love and Monsters
# Dick Johnson Is Dead’: A Father not found
# Found Love, Guaranteed
# Found Feel the Beat
# Found Babyteeth
# Found Spelling the Dream
# A Secret Love’: A Lesbian Couple not found
# Found Love Wedding Repeat
# Found Almost Love
# Found Hope Gap
# Found All the Bright Places
# Found The Photograph
# Found You Go to My Head
# Found Ordinary Love
# Found To All the Boys: P.S. I Still Love You
# Found The Woman Who Loves Giraffes
# Found Queen & Slim
# Found Marriage Story
# Found Cyrano, My Love
# Found Pretenders
# Found First Love
# Found Loro
# Found Falling Inn Love
# Found Hot Air
# Love, Antosha’: A Heartbreaking Look at an Actor not found
# Found Leto
# Found The Tomorrow Man
# Found Asako I & II
# Found The Sun Is Also a Star
# Found Shéhérazade
# Found Long Shot
# Clara’: Love Means Never Having to Say You not found
# Found Kalank
# Found Rafiki
# Found Diane
# Found Five Feet Apart
# Found Ash Is Purest White
# Found Gloria Bell
# Found Black Mother
# The Hole in the Ground’: A Horror Film Is Suffocated by a Mother not found
# Found How to Train Your Dragon: The Hidden World
# Found A Tuba to Cuba
# Found Fighting With My Family
# Found Sorry Angel
# Found Berlin, I Love You
# Found Untogether
# Found Cold War
# Found If Beale Street Could Talk
# Found Asher
# Found The Party’s Just Beginning
# Found The Great Pretender
# Found Sicilian Ghost Story
# Found The New Romantic
# Found Pimp
# Found In a Relationship
# They’ll Love Me When I’m Dead’ Documents Orson Welles not found
# Found Burning,
# Found After Everything,
# Found Quincy
# Found Love, Gilda,
# Found Tea With the Dames,
# Found Bel Canto,
# Found The Citizen,
# Found Love, Cecil,
# Found How to Talk to Girls at Parties
# Found Rogers Park,
# Found Love & Bananas,
# Found Godard Mon Amour
# Found Submergence,
# Found Love After Love,
# Found Outside In
# Found Love, Simon,
# Found Keep the Change,
# Found The Party
# Found The Housemaid,
# Found Forever My Girl,
# Found Kangaroo: A Love-Hate Story
# Found Lover for a Day
# Found Youth,’ the People
# Found Killing for Love
# Found The Shape of Water
# Found Love Beats Rhymes,
# Found Cuba and the Cameraman
# Found On the Beach at Night Alone
# Found Thelma,
# Found Hello Again,
# Found It Happened in L.A.,
# Found God’s Own Country
# Found The Mountain Between Us
# Found Dina,
# Found In Search of Fellini
# Found Woodpeckers,
# Found I Do ... Until I Don’t,
# Found Tales of an Immoral Couple
# Found After Love
# Found The Last Face
# Found Women Who Kill,
# False Confessions,’ the Play not found
# Review: Those Movies, Himself — Bertrand Tavernier’s Tour of French Cinema not found
# Found The Big Sick,
# Found Lost in Paris
# Found Vincent N Roxxy,
# Found Everything, Everything

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmdb_movies_list[:5], indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "release_date": "2021-10-07",
#         "budget": 0,
#         "revenue": 0,
#         "genres": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "production_countries": [
#             "Argentina"
#         ]
#     },
#     {
#         "title": "What's Love Got to Do with It?",
#         "release_date": "2023-01-26",
#         "budget": 0,
#         "revenue": 10898395,
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "Urdu",
#             "Portuguese"
#         ],
#         "production_countries": [
#             "France",
#             "United Kingdom"
#         ]
#     },
#     {
#         "title": "You Can Live Forever",
#         "release_date": "2023-03-24",
#         "budget": 0,
#         "revenue": 15055,
#         "genres": [
#             "Drama",
#             "Romance"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "Canada"
#         ]
#     },
#     {
#         "title": "A Tourist's Guide to Love",
#         "release_date": "2023-04-21",
#         "budget": 0,
#         "revenue": 0,
#         "genres": [
#             "Romance",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "Vietnamese"
#         ],
#         "production_countries": [
#             "United States of America"
#         ]
#     },
#     {
#         "title": "Other People's Children",
#         "release_date": "2022-09-21",
#         "budget": 0,
#         "revenue": 84178,
#         "genres": [
#             "Drama",
#             "Comedy"
#         ],
#         "spoken_languages": [
#             "English",
#             "French"
#         ],
#         "production_countries": [
#             "France"
#         ]
#     }
# ]

# %%
# Convert the results to a DataFrame
tmdb_movies_df = pd.DataFrame(tmdb_movies_list)
tmdb_movies_df.head()
# Out:
#                             title release_date  budget   revenue  \
# 0          The Attachment Diaries   2021-10-07       0         0
# 1  What's Love Got to Do with It?   2023-01-26       0  10898395
# 2            You Can Live Forever   2023-03-24       0     15055
# 3       A Tourist's Guide to Love   2023-04-21       0         0
# 4         Other People's Children   2022-09-21       0     84178
#
#                                genres             spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]                    [Spanish]
# 1                   [Romance, Comedy]  [English, Urdu, Portuguese]
# 2                    [Drama, Romance]            [English, French]
# 3                   [Romance, Comedy]        [English, Vietnamese]
# 4                     [Drama, Comedy]            [English, French]
#
#          production_countries
# 0                 [Argentina]
# 1    [France, United Kingdom]
# 2                    [Canada]
# 3  [United States of America]
# 4                    [France]

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(reviews_df, tmdb_movies_df, on="title")
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;persons: Bracey, Luke (1989- )...
# 3  subject: Documentary Films and Programs;creati...
# 4  subject: Movies;creative_works: A Thousand and...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-13T11:00:06+0000         320
# 3  2023-04-13T11:00:03+0000         327
# 4  2023-03-30T18:53:42+0000         971
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#   headline.content_kicker                  headline.print_headline  ...  \
# 0                    None                   The Attachment Diaries  ...
# 1                    None                     You Can Live Forever  ...
# 2                    None                           One True Loves  ...
# 3                    None          The Lost Weekend:  A Love Story  ...
# 4                    None  An Unbending Will Meets a Shifting City  ...
#
#             byline.original  \
# 0    By Jeannette Catsoulis
# 1  By Elisabeth Vincentelli
# 2             By Brandon Yu
# 3            By Glenn Kenny
# 4         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  [{'firstname': 'Jeannette', 'middlename': None...                None
# 1  [{'firstname': 'Elisabeth', 'middlename': None...                None
# 2  [{'firstname': 'Brandon', 'middlename': None, ...                None
# 3  [{'firstname': 'Glenn', 'middlename': None, 'l...                None
# 4  [{'firstname': 'Manohla', 'middlename': None, ...                None
#
#                             title release_date budget  revenue  \
# 0          The Attachment Diaries   2021-10-07      0        0
# 1            You Can Live Forever   2023-03-24      0    15055
# 2                  One True Loves   2023-04-07      0    37820
# 3  The Lost Weekend: A Love Story   2023-04-13      0    77145
# 4              A Thousand and One   2023-03-31      0  3395595
#
#                                genres                spoken_languages  \
# 0  [Drama, Mystery, Thriller, Horror]                       [Spanish]
# 1                    [Drama, Romance]               [English, French]
# 2            [Romance, Drama, Comedy]                       [English]
# 3                       [Documentary]                       [English]
# 4                      [Drama, Crime]  [English, Spanish, Portuguese]
#
#                   production_countries
# 0                          [Argentina]
# 1                             [Canada]
# 2  [Germany, United States of America]
# 3           [United States of America]
# 4           [United States of America]
#
# [5 rows x 23 columns]

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
columns_to_fix = ["genres", "spoken_languages", "production_countries", "byline.person"]


# Create a list of characters to remove
characters_to_remove = ["[", "]", "\"", "{","}", "'"]


# Loop through the list of columns to fix
for column in columns_to_fix:

    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)
    # Loop through characters to remove
    for character in characters_to_remove:
        # Remove the character
        merged_df[column] = merged_df[column].str.replace(character, "")


# Display the fixed DataFrame
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;persons: Bracey, Luke (1989- )...
# 3  subject: Documentary Films and Programs;creati...
# 4  subject: Movies;creative_works: A Thousand and...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-13T11:00:06+0000         320
# 3  2023-04-13T11:00:03+0000         327
# 4  2023-03-30T18:53:42+0000         971
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#   headline.content_kicker                  headline.print_headline  ...  \
# 0                    None                   The Attachment Diaries  ...
# 1                    None                     You Can Live Forever  ...
# 2                    None                           One True Loves  ...
# 3                    None          The Lost Weekend:  A Love Story  ...
# 4                    None  An Unbending Will Meets a Shifting City  ...
#
#             byline.original  \
# 0    By Jeannette Catsoulis
# 1  By Elisabeth Vincentelli
# 2             By Brandon Yu
# 3            By Glenn Kenny
# 4         By Manohla Dargis
#
#                                        byline.person byline.organization  \
# 0  firstname: Jeannette, middlename: None, lastna...                None
# 1  firstname: Elisabeth, middlename: None, lastna...                None
# 2  firstname: Brandon, middlename: None, lastname...                None
# 3  firstname: Glenn, middlename: None, lastname: ...                None
# 4  firstname: Manohla, middlename: None, lastname...                None
#
#                             title release_date budget  revenue  \
# 0          The Attachment Diaries   2021-10-07      0        0
# 1            You Can Live Forever   2023-03-24      0    15055
# 2                  One True Loves   2023-04-07      0    37820
# 3  The Lost Weekend: A Love Story   2023-04-13      0    77145
# 4              A Thousand and One   2023-03-31      0  3395595
#
#                              genres              spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror                       Spanish
# 1                    Drama, Romance               English, French
# 2            Romance, Drama, Comedy                       English
# 3                       Documentary                       English
# 4                      Drama, Crime  English, Spanish, Portuguese
#
#                 production_countries
# 0                          Argentina
# 1                             Canada
# 2  Germany, United States of America
# 3           United States of America
# 4           United States of America
#
# [5 rows x 23 columns]

# %%
# Drop "byline.person" column
merged_df.drop(columns="byline.person", inplace=True)

# %%
# Delete duplicate rows and reset index
merged_df.drop_duplicates(inplace=True)
merged_df.reset_index(drop=True, inplace=True)
merged_df.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/25/movies/the-...
# 1  https://www.nytimes.com/2023/05/04/movies/you-...
# 2  https://www.nytimes.com/2023/04/13/movies/one-...
# 3  https://www.nytimes.com/2023/04/13/movies/the-...
# 4  https://www.nytimes.com/2023/03/30/movies/a-th...
#
#                                              snippet              source  \
# 0  A gynecologist and her patient form a horrifyi...  The New York Times
# 1  Religion comes between two girls falling in lo...  The New York Times
# 2  A film adaptation of Taylor Jenkins Reid’s nov...  The New York Times
# 3  There’s not much Lennon music heard in this do...  The New York Times
# 4  A mesmerizing Teyana Taylor stars in A.V. Rock...  The New York Times
#
#                                             keywords  \
# 0  subject: Movies;creative_works: The Attachment...
# 1  subject: Movies;creative_works: You Can Live F...
# 2  subject: Movies;persons: Bracey, Luke (1989- )...
# 3  subject: Documentary Films and Programs;creati...
# 4  subject: Movies;creative_works: A Thousand and...
#
#                    pub_date  word_count  \
# 0  2023-05-25T11:00:03+0000         295
# 1  2023-05-04T11:00:08+0000         294
# 2  2023-04-13T11:00:06+0000         320
# 3  2023-04-13T11:00:03+0000         327
# 4  2023-03-30T18:53:42+0000         971
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# 1  ‘You Can Live Forever’ Review: Do You Love Me ...            None
# 2     ‘One True Loves’ Review: A Romance Lost at Sea            None
# 3  ‘The Lost Weekend: A Love Story’ Review: When ...            None
# 4  ‘A Thousand and One’ Review: A New York Love S...   Critic’s Pick
#
#   headline.content_kicker                  headline.print_headline  ...  \
# 0                    None                   The Attachment Diaries  ...
# 1                    None                     You Can Live Forever  ...
# 2                    None                           One True Loves  ...
# 3                    None          The Lost Weekend:  A Love Story  ...
# 4                    None  An Unbending Will Meets a Shifting City  ...
#
#   headline.sub           byline.original byline.organization  \
# 0         None    By Jeannette Catsoulis                None
# 1         None  By Elisabeth Vincentelli                None
# 2         None             By Brandon Yu                None
# 3         None            By Glenn Kenny                None
# 4         None         By Manohla Dargis                None
#
#                             title release_date budget  revenue  \
# 0          The Attachment Diaries   2021-10-07      0        0
# 1            You Can Live Forever   2023-03-24      0    15055
# 2                  One True Loves   2023-04-07      0    37820
# 3  The Lost Weekend: A Love Story   2023-04-13      0    77145
# 4              A Thousand and One   2023-03-31      0  3395595
#
#                              genres              spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror                       Spanish
# 1                    Drama, Romance               English, French
# 2            Romance, Drama, Comedy                       English
# 3                       Documentary                       English
# 4                      Drama, Crime  English, Spanish, Portuguese
#
#                 production_countries
# 0                          Argentina
# 1                             Canada
# 2  Germany, United States of America
# 3           United States of America
# 4           United States of America
#
# [5 rows x 22 columns]

# %%
# Export data to CSV without the index
merged_df.to_csv("output/nyt_movie_reviews.csv", index=False)
